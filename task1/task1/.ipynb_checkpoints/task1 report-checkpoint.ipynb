# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Входные параметры - количество реализаций в выборке N и $\theta$ - параметр распределения (согласно заданию, распределение равномерное от 0 до $\theta$). sample - выборкаю

# %%
N = 10**4
theta = 5

sample = theta*np.random.rand(N)

# %% [markdown]
# Определяем функции оценок. Каждая принимает на вход n - размер выборки, для которого нужно считать оценкую

# %%
def est0(n, row=sample):
    return 2*sum(row[:n])/float(n)


def est1(n, row=sample):
    return est0(n, row)*0.5 + row[:n]*0.5


def est2(n, row=sample):
    return (n+1)*row[0]


def est3(n, row=sample):
    return row[0] + row[n-1]


def est4(n, row=sample):
    return (n+1)/float(n)*row[n-1]

est_functions = [est0, est1, est2, est3, est4]

# %% [markdown]
# Считаем модули разности оценок и $\theta$ для каждого значения $n\leq N$.

# %%
est_rows = [[],[],[],[],[]]
for n in range(N+1)[1:]:
    for i in range(5):
        est_rows[i].append(np.abs(est_functions[i](n) - theta))

# %% [markdown]
# Строим графики.

# %%
est_colors = ['r', 'g', 'b', 'y', 'm']
est_labels = ['2$\overline{X}$', '$\overline{X} + {X_{n}}/{2}$', '(n+1)$X_1$', '$X_1 + X_n$', '${(n+1)}/{n}X_n$']

def plot_rows(limits=None, rows=est_rows):
    for i in range(len(rows)):
        plt.plot(range(N+1)[1:], rows[i], color=est_colors[i], label=est_labels[i])
        plt.legend()
    if limits:
        plt.axis(limits)
    plt.show()
    
plot_rows()

# %% [markdown]
# Из графика видно, что оценка $(n+1)X_1$ линейно уходит от $\theta$ (ожидаемо, ведь это просто линейная функция от n с коэффицентом, равным первому выпавшему значению). Будем строить графики без нее. Для остальных оценок строю три графика - для значений n от 0 до 100, от N/2 до N/2+100 и от N-100 до N соответственно.

# %%
if len(est_rows) == 5:
    del est_rows[2]
    del est_colors[2]
    del est_labels[2]
    del est_functions[2]
plot_rows([0, 100, 0.0, 1.1*theta])
plot_rows([N/2, N/2 + 100, 0.0, 1.1*theta])
plot_rows([N - 100, N, 0.0, 1.1*theta])

# %% [markdown]
# Проверим оценки (кроме 2ой) для разных значений $\theta$

# %%
def deal_with_theta(new_theta, scale):
    new_sample = new_theta*np.random.rand(N)
    new_rows = [[],[],[],[]]
    for n in range(N+1)[1:]:
        for i in range(4):
            new_rows[i].append(np.abs(est_functions[i](n, new_sample) - new_theta))
    plot_rows([0, 100, 0.0, scale*new_theta], new_rows)
    plot_rows([N/2, N/2 + 100, 0.0, scale*new_theta], new_rows)
    plot_rows([N - 100, N, 0.0, scale*new_theta], new_rows)

# %% [markdown]
# $\theta = 1$

# %%
deal_with_theta(1, 1.1)

# %% [markdown]
# $\theta = 10$

# %%
deal_with_theta(10, 1.1)

# %% [markdown]
# $\theta = 100$

# %%
deal_with_theta(100, 1.1)

# %% [markdown]
# $\theta = 1000$

# %%
deal_with_theta(1000, 1.1)
